# %% [markdown]
# # Low Rank Factorization

# %%
import sys
sys.path.insert(0, r'E:\GitHub\molass-library')
sys.path.insert(0, r'E:\GitHub\molass-legacy')
from molass.Local import get_local_settings
local_settings = get_local_settings()
TUTORIAL_DATA = local_settings['TUTORIAL_DATA']
print(TUTORIAL_DATA)
from molass.DataObjects import SecSaxsData as SSD
ssd = SSD(TUTORIAL_DATA)
ssd.plot_3d();
# Out:
# E:\MolassData\tutorial_data

# %%
from molass.SAXS.DenssTools import exec_denss
trimmed_ssd = ssd.trimmed_copy()
corrected_ssd = trimmed_ssd.corrected_copy()
lrf_info = corrected_ssd.quick_lowrank_info()
lrf_info.plot_components()
# Out:
# developper memo: remember that "LowRank.CoupledAdjuster.select_components" is not implemented yet.

# %%
data = lrf_info.get_data_for_denss()
exec_denss(data)
# Out:
# WARNING: Only 2 columns given. Data should have 3 columns: q, I, errors.
# WARNING: Setting error bars to 1.0 (i.e., ignoring error bars)
# Dmax = 129.43
# Number of experimental Shannon channels: 11
# Number of calculated Shannon channels: 33
# Scanning alphas... 100% complete
# WARNING: Only 2 columns given. Data should have 3 columns: q, I, errors.
# WARNING: Setting error bars to 1.0 (i.e., ignoring error bars)
# Dmax = 143.72
# Number of experimental Shannon channels: 37
# Number of calculated Shannon channels: 112
#
# q, I, sigq: 1765 1765 1765
# qc, ac, ec: 2766 2766 2766
#
#  Step     Chi2     Rg    Support Volume
#  ----- --------- ------- --------------
#   620   3.09e-01  88.15        1698782
# switched to shrinkwrap by density threshold = 0.2000
#   999   3.77e-02  64.29        503580          EC: 2 -> 1
#  3412   1.40e-05  36.27        354371

# %%
from importlib import reload
import molass.SAXS.MrcViewer
reload(molass.SAXS.MrcViewer)
from molass.SAXS.MrcViewer import show_mrc
show_mrc('data_name.mrc')
# Out:
# boundary= 6.526005e-05
# (812, 3)
#   File "E:\GitHub\molass-legacy\molass_legacy\Saxs\EdPlotter.py", line 79, in __init__
#     ret = get_log_items(folder + '/denss.log')
#                         ^^^^^^
# NameError: name 'folder' is not defined. Did you mean: 'filter'?
